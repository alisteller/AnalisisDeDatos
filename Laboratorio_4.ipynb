# %% [markdown]
# <a href="https://colab.research.google.com/github/alisteller/AnalisisDeDatos/blob/main/Laboratorio_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium

# %%
from folium.plugins import minimap

# %%
#CR = folium.Map(location=(9.921199334412426, -84.09780057905037))
#CR

poptextPerez = '<b> Universidad Nacional Perez Zeledón </b>'
poptextHeredia = '<b> Universidad Nacional Heredia-Omar Dengo </b>'
poptextBenjamin = '<b> Universidad Nacional Heredia-Benjamin Nuñez </b>'
poptextSarapiqui = '<b> Universidad Nacional Heredia-Sarapiqui </b>'
poptextAlajuela = '<b> Universidad Nacional Alajuela </b>'
poptextNicoya = '<b> Universidad Nacional Guanacaste-Nicoya </b>'
poptextLiberia = '<b> Universidad Nacional Guanacaste-Liberia </b>'
poptextCiudadNeily = '<b> Universidad Nacional Ciudad Neily </b>'

my_map = folium.Map(location=(9.921975710435847, -84.09521739270373))

# %%
folium.Marker(location=[9.380793426717892, -83.69180126450634],popup=poptextPerez,icon=folium.Icon(color="red",icon="ok-sign")).add_to(my_map)
folium.Marker(location=[9.99901577155464, -84.11139085913706],popup=poptextHeredia,icon=folium.Icon(color="red",icon="ok-sign")).add_to(my_map)
folium.Marker(location=[9.969647162488693, -84.12782261655269],popup=poptextBenjamin,icon=folium.Icon(color="red",icon="ok-sign")).add_to(my_map)
folium.Marker(location=[10.31923446399595, -83.92278999014552],popup=poptextSarapiqui,icon=folium.Icon(color="red",icon="ok-sign")).add_to(my_map)
folium.Marker(location=[10.019881772442107, -84.19701460364094],popup=poptextAlajuela,icon=folium.Icon(color="red",icon="ok-sign")).add_to(my_map)
folium.Marker(location=[10.134723564266855, -85.44667655946257],popup=poptextNicoya,icon=folium.Icon(color="red",icon="ok-sign")).add_to(my_map)
folium.Marker(location=[10.61761228614435, -85.45133217295266],popup=poptextLiberia,icon=folium.Icon(color="red",icon="ok-sign")).add_to(my_map)
folium.Marker(location=[8.57375280451463, -82.87240377306281],popup=poptextCiudadNeily,icon=folium.Icon(color="red",icon="ok-sign")).add_to(my_map)


my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
